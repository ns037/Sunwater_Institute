# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
invalidation = pd.read_csv('DirectApplications.csv')

# %%
invalidation
# Out:
#    CountryOffice   Year  Fillings  Grants  Acceptance  Invalidation
# 0           China  2016   1257448  336695    0.267761        0.7322
# 1           China  2017   1301292  361216    0.277583        0.7224
# 2           China  2018   1457705  380312    0.260898        0.7391
# 3           China  2019   1311412  396428    0.302291        0.6977
# 4           Japan  2005    381791  116306    0.304633        0.6954
# ..            ...   ...       ...     ...         ...           ...
# 65         Europe  2017     68160   37725    0.553477        0.4465
# 66         Europe  2018     72229   44411    0.614864        0.3851
# 67         Europe  2019     75810   48201    0.635813        0.3642
# 68         Europe  2020     73495   47705    0.649092        0.3509
# 69         Europe  2021     73673   39552    0.536859        0.4631
#
# [70 rows x 6 columns]

# %%
invalidation.columns
# Out:
# Index(['CountryOffice ', 'Year', 'Fillings', 'Grants', 'Acceptance',
#        'Invalidation'],
#       dtype='object')

# %%
country_group = invalidation.groupby('CountryOffice ')
country_group

# %%
invalidation['log_fillings'] = np.log(invalidation['Fillings'])

# %%
invalidation['log10_grants'] = np.log10(invalidation['Grants'])

# %%
country_group = invalidation.groupby('CountryOffice ')
country_group

for country, data in country_group:
    plt.plot(data['Year'], data['log10_grants'], label=country)

# Add labels and a legend
plt.xlabel('Year')
plt.ylabel('log10 Grants')
plt.legend()

# Display the plot
plt.show()

# %%
invalidation['log10_fillings'] = np.log10(invalidation['Fillings'])

# %%
country_group = invalidation.groupby('CountryOffice ')
country_group

for country, data in country_group:
    plt.plot(data['Year'], data['Grants'], label=country)

# Add labels and a legend
plt.xlabel('Year')
plt.ylabel('Grants')
plt.legend()

# Display the plot
plt.show()

# %%
for country, data in country_group:
    plt.plot(data['Year'], data['Fillings'], label=country)

# Add labels and a legend
plt.xlabel('Year')
plt.ylabel('Fillings')
plt.legend()

# Display the plot
plt.show()

# %%
for country, data in country_group:
    plt.plot(data['Year'], data['Invalidation'], label=country)

# Add labels and a legend
plt.xlabel('Year')
plt.ylabel('Invalidation')
plt.legend()

# Add point markers to mark observations
for country, data in country_group:
    plt.scatter(data['Year'], data['Invalidation'], label=f'{country} - Observation', s=20, marker='o')


# Customize x-axis ticks to show more distinctions
plt.xticks(invalidation['Year'].unique(),rotation = 90)

# Display the plot
plt.show()

# %%
examination = pd.read_csv('ExaminationFee.csv')
examination
# Out:
#    Country   Year     Fee
# 0        US  2021  800.00
# 1        US  2020  760.00
# 2        US  2019  760.00
# 3        US  2018  760.00
# 4        US  2017  720.00
# ..      ...   ...     ...
# 73    China  2015  401.45
# 74    China  2016  376.25
# 75    China  2017  369.89
# 76    China  2018  377.87
# 77    China  2019  361.88
#
# [78 rows x 3 columns]

# %%
country_group = examination.groupby('Country ')

for country, data in country_group:
    plt.plot(data['Year'], data['Fee'], label=country)

# Add labels and a legend
plt.xlabel('Year')
plt.ylabel('Examination Fees($)')
plt.legend()

# Add point markers to mark observations
for country, data in country_group:
    plt.scatter(data['Year'], data['Fee'], label=f'{country} - Observation', s=30, marker='o')


# Customize x-axis ticks to show more distinctions
plt.xticks(invalidation['Year'].unique(),rotation = 90)

# Display the plot
plt.show()

# %%
appeal = pd.read_csv('AppealOnlineFee.csv')

# %%
appeal
# Out:
#    Country   Year      Fee
# 0    Europe  2005  1268.97
# 1    Europe  2006  1337.21
# 2    Europe  2007  1459.56
# 3    Europe  2008  1647.25
# 4    Europe  2009  1562.16
# ..      ...   ...      ...
# 62       US  2017   800.00
# 63       US  2018   800.00
# 64       US  2019   800.00
# 65       US  2020   800.00
# 66       US  2021   840.00
#
# [67 rows x 3 columns]

# %%
country_group = appeal.groupby('Country ')

for country, data in country_group:
    plt.plot(data['Year'], data['Fee'], label=country)

# Add labels and a legend
plt.xlabel('Year')
plt.ylabel('Appeal Fees($)')
plt.legend()

# Add point markers to mark observations
for country, data in country_group:
    plt.scatter(data['Year'], data['Fee'], label=f'{country} - Observation', s=30, marker='o')


# Customize x-axis ticks to show more distinctions
plt.xticks(invalidation['Year'].unique(),rotation = 90)

# Display the plot
plt.show()

# %%
kipo = pd.read_csv('KipoGrantIpc2021.csv')
kipo.describe()
# Out:
#               Total
# count    122.000000
# mean    1195.754098
# std     2446.741835
# min        1.000000
# 25%      117.500000
# 50%      498.000000
# 75%     1004.750000
# max    15975.000000

# %%
kipo10 = kipo.sort_values(by = 'Total', ascending=False).head(10) 

kipo10.plot( x = 'IPC', y = 'Total', kind = 'bar')
plt.show()

# %%
epo = pd.read_csv('EpoGrantsIPC2021.csv')
epo.describe()
# Out:
#               Total
# count    122.000000
# mean     891.786885
# std     1921.910006
# min        1.000000
# 25%       88.250000
# 50%      287.500000
# 75%      747.250000
# max    13414.000000

# %%
epo10 = epo.sort_values(by = 'Total', ascending=False).head(10)

epo10.plot( x = 'IPC', y = 'Total', kind = 'bar')
plt.show()

# %%
jpo = pd.read_csv('JpoGrantsIPC2020.csv')
jpo.describe()
# Out:
#               Total
# count    123.000000
# mean    1458.382114
# std     2720.888487
# min        2.000000
# 25%      133.500000
# 50%      460.000000
# 75%     1433.000000
# max    15688.000000

# %%
jpo10 = jpo.sort_values(by = 'Total', ascending=False).head(10)

jpo10.plot( x = 'IPC', y = 'Total', kind = 'bar')
plt.show()

# %%
cnipa = pd.read_csv('CnipaGrantIPC2019.csv')
cnipa.describe()
# Out:
#               Total
# count    124.000000
# mean    3651.645161
# std     7657.992978
# min        0.000000
# 25%      404.250000
# 50%     1419.500000
# 75%     3252.750000
# max    51207.000000

# %%
cnipa[cnipa.Total != 0].describe()
# Out:
#               Total
# count    123.000000
# mean    3681.333333
# std     7682.145801
# min        7.000000
# 25%      409.000000
# 50%     1425.000000
# 75%     3272.500000
# max    51207.000000

# %%
cnipa10 = cnipa.sort_values(by = 'Total', ascending=False).head(10)

cnipa10.plot( x = 'IPC', y = 'Total', kind = 'bar')
plt.show()

# %%
uspto = pd.read_csv('UsptoGrantsIPC2021.csv')

uspto.describe()
# Out:
#               Total
# count    123.000000
# mean    2661.130081
# std     7585.402089
# min        1.000000
# 25%      181.000000
# 50%      519.000000
# 75%     2118.000000
# max    57792.000000

# %%
uspto10 = uspto.sort_values(by = 'Total', ascending=False).head(10)

uspto10.plot( x = 'IPC', y = 'Total', kind = 'bar')
plt.show()

# %%
cnipa5 = cnipa10.head(5)
cnipa5['Country'] = ['China' for i in range(5)]
cnipa5
# Out:
# /var/folders/h1/_0238p116qdc782gkpb3sd000000gp/T/ipykernel_11305/3638904211.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cnipa5['Country'] = ['China' for i in range(5)]
#      IPC  Total Country
# 122  H04  51207   China
# 110  G06  42424   China
# 105  G01  37715   China
# 119  H01  33297   China
# 12   A61  17691   China

# %%
uspto5 = uspto10.head(5)
uspto5['Country'] = ['US' for i in range(5)]
uspto5
# Out:
# /var/folders/h1/_0238p116qdc782gkpb3sd000000gp/T/ipykernel_11305/2257785110.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uspto5['Country'] = ['US' for i in range(5)]
#      IPC  Total Country
# 109  G06  57792      US
# 121  H04  44549      US
# 118  H01  29930      US
# 12   A61  29545      US
# 104  G01  16276      US

# %%
epo5 = epo10.head(5)
epo5['Country'] = ['Europe' for i in range(5)]
epo5
# Out:
# /var/folders/h1/_0238p116qdc782gkpb3sd000000gp/T/ipykernel_11305/3374392289.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   epo5['Country'] = ['Europe' for i in range(5)]
#      IPC  Total Country
# 120  H04  13414  Europe
# 12   A61  12074  Europe
# 104  G01   6519  Europe
# 109  G06   6241  Europe
# 117  H01   6060  Europe

# %%
kipo5 = kipo10.head(5)
kipo5['Country'] = ['Korea' for i in range(5)]
kipo5
# Out:
# /var/folders/h1/_0238p116qdc782gkpb3sd000000gp/T/ipykernel_11305/163210690.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kipo5['Country'] = ['Korea' for i in range(5)]
#      IPC  Total Country
# 117  H01  15975   Korea
# 108  G06  14600   Korea
# 12   A61  10777   Korea
# 120  H04  10651   Korea
# 103  G01   6793   Korea

# %%
jpo5 = jpo10.head(5)
jpo5['Country'] = ['Japan' for i in range(5)]
jpo5
# Out:
# /var/folders/h1/_0238p116qdc782gkpb3sd000000gp/T/ipykernel_11305/1981578209.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jpo5['Country'] = ['Japan' for i in range(5)]
#      IPC  Total Country
# 118  H01  15688   Japan
# 109  G06  12978   Japan
# 12   A61  12810   Japan
# 121  H04  11262   Japan
# 104  G01  10073   Japan

# %%
merged_df = pd.concat([uspto5,jpo5,kipo5,epo5,cnipa5],ignore_index=True)
merged_df
# Out:
#     IPC  Total Country
# 0   G06  57792      US
# 1   H04  44549      US
# 2   H01  29930      US
# 3   A61  29545      US
# 4   G01  16276      US
# 5   H01  15688   Japan
# 6   G06  12978   Japan
# 7   A61  12810   Japan
# 8   H04  11262   Japan
# 9   G01  10073   Japan
# 10  H01  15975   Korea
# 11  G06  14600   Korea
# 12  A61  10777   Korea
# 13  H04  10651   Korea
# 14  G01   6793   Korea
# 15  H04  13414  Europe
# 16  A61  12074  Europe
# 17  G01   6519  Europe
# 18  G06   6241  Europe
# 19  H01   6060  Europe
# 20  H04  51207   China
# 21  G06  42424   China
# 22  G01  37715   China
# 23  H01  33297   China
# 24  A61  17691   China

# %%
# Pivot the data to create a DataFrame suitable for a stacked bar chart
pivot_df = merged_df.pivot(index='IPC', columns='Country', values='Total')

# Plot a stacked bar chart
ax = pivot_df.plot(kind='bar', stacked=True, figsize=(10, 6))

# Customize the chart
plt.xlabel('IPC')
plt.ylabel('Total')
plt.title('Stacked Bar Chart by IPC and Country')

plt.show()

# %%
total = uspto.Total.sum()
total
# Out:
# 327319

# %%
uspto['Percent_grants'] = uspto['Total']*100/total

# %%
usptotop10 = uspto.sort_values(by = 'Percent_grants', ascending=False).head(10)
usptotop10.plot( x = 'IPC', y = 'Percent_grants', kind = 'bar')
plt.show()

# %%
usptotop10.head(5).Percent_grants.sum()
# Out:
# 54.409307128519885

# %%
utility
# Out:
#          Examiner  Allowance  Final Rejection  Non-Final Rejection  Total
# 0  Junior-Primary        345              344                  540    1229
# 1      Junior-SPE        390              445                  650    1485
# 2         Primary       3570             1593                 3616    8779

# %%
utility = pd.read_csv('examiner-utility-patent.csv')
utility.describe()
# Out:
#          Allowance  Final Rejection  Non-Final Rejection       Total
# count     3.000000         3.000000              3.00000     3.000000
# mean   1435.000000       794.000000           1602.00000  3831.000000
# std    1849.101133       693.794638           1745.04212  4287.005015
# min     345.000000       344.000000            540.00000  1229.000000
# 25%     367.500000       394.500000            595.00000  1357.000000
# 50%     390.000000       445.000000            650.00000  1485.000000
# 75%    1980.000000      1019.000000           2133.00000  5132.000000
# max    3570.000000      1593.000000           3616.00000  8779.000000

# %%
plt.scatter(x=utility.Examiner, y=utility.Allowance)
plt.show()

# %%
utility1 = utility.iloc[:,0:3]

# %%
# Plotting
fig, ax = plt.subplots(figsize=(10, 6))
utility1.plot(kind='bar', stacked=True, ax=ax)

# Adding labels and title
plt.xlabel('Examiner')
plt.ylabel('Count')
plt.title('Stacked Bar Chart of Examiner Data')

# Show the plot
plt.show()

# %%
df_percentage = utility.divide(utility['Total '], axis=0) * 100

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))
df_percentage.drop('Total ', axis=1).plot(kind='bar', stacked=True, ax=ax)

# Adding labels and title
plt.xlabel('Examiner')
plt.ylabel('Percentage')
plt.title('Stacked Bar Chart as Percentage of Total')

# Show the plot
plt.show()

# %%
utility.columns
# Out:
# Index(['Allowance', 'Final Rejection', 'Non-Final Rejection', 'Total '], dtype='object')
